# %%
import requests

def annotate_text_with_dbpedia(text):
    spotlight_url = "http://api.dbpedia-spotlight.org/en/annotate"
    headers = {'Accept': 'application/json'}
    params = {'text': text, 'confidence': 0.5}
    response = requests.get(spotlight_url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# Example usage
text = "Barack Obama was the president of the United States."
annotations = annotate_text_with_dbpedia(text)
print(annotations)
# Out:
# {'@text': 'Barack Obama was the president of the United States.', '@confidence': '0.5', '@support': '0', '@types': '', '@sparql': '', '@policy': 'whitelist', 'Resources': [{'@URI': 'http://dbpedia.org/resource/Barack_Obama', '@support': '27440', '@types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q82955,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Person,DBpedia:Agent,DBpedia:Politician', '@surfaceForm': 'Barack Obama', '@offset': '0', '@similarityScore': '0.9999750765811097', '@percentageOfSecondRank': '1.2731717656137947E-5'}, {'@URI': 'http://dbpedia.org/resource/United_States', '@support': '553243', '@types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country', '@surfaceForm': 'United States', '@offset': '38', '@similarityScore': '0.9999326809092367', '@percentageOfSecondRank': '4.953675667499674E-5'}]}

# %%
import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def calculate_similarity(text1, text2):
    doc1 = nlp(text1)
    doc2 = nlp(text2)
    return doc1.similarity(doc2)

# Example usage
similarity = calculate_similarity("fast car", "speedy vehicle")
print(similarity)
# Out:
# 0.7017164834136657
# /var/folders/b5/6fdjjrb57ln9w5w1477gvmbr0000gn/T/ipykernel_14185/1178475645.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   return doc1.similarity(doc2)

# %%
# Filter Relations & Match Node Name to Entity

import pandas as pd
from textblob import TextBlob
import re

# %%
input_path = "../data_intermediate"
output_path = "../data_intermediate"

raw_relations = pd.read_csv(input_path + "/raw_relations.csv", index_col = 0)
entities = pd.read_csv(input_path + "/entity_list.csv", index_col = 0)

# %%
# Create entity list
entity_set = set(list(entities['ent_name']))

# Add fixed key words as entities
fixed_set = ["lgbt", 'dei', 'diversity']
for ent in fixed_set:
    entity_set.add(ent)

# %%
# First transformation: extract nouns from subject, object
def extract_nouns(text):
    blob = TextBlob(text)
    return blob.noun_phrases

raw_relations['node1_t1'] = raw_relations.apply(lambda x: extract_nouns(x['subject']), axis = 1)
raw_relations['node2_t1'] = raw_relations.apply(lambda x: extract_nouns(x['object']), axis = 1)
raw_relations[:10]
# Out:
#    news_id                    subject        relation               object  \
# 0        0               Pope Francis           Calls           Deplorable
# 1        0  Catholic leader ’s stance              is               likely
# 2        0               many members  have relied on             practice
# 3        0                    members            have       their children
# 4        0           leader ’s stance            roil       LGBT community
# 5        0            Catholic leader              ’s  stance on surrogacy
# 6        0                    members            have   their own children
# 7        0           leader ’s stance              is               likely
# 8        0                    members  have relied on             practice
# 9        0               many members            have   their own children
#
#                        node1_t1        node2_t1
# 0                [pope francis]              []
# 1  [catholic leader ’ s stance]              []
# 2                            []              []
# 3                            []              []
# 4           [leader ’ s stance]          [lgbt]
# 5             [catholic leader]              []
# 6                            []  [own children]
# 7           [leader ’ s stance]              []
# 8                            []              []
# 9                            []  [own children]

# %%
import requests

def get_dbpedia_resource(text):
    url = "http://api.dbpedia-spotlight.org/en/annotate"
    headers = {'Accept': 'application/json'}
    params = {'text': text, 'confidence': 0.5}  # For now we use confidence level > 0.5
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            resources = data.get('Resources', [])
            if resources:
                return resources[0]['@URI']  # Return the URI of the first resource
    except Exception as e:
        print(f"Error querying DBpedia Spotlight: {e}")
    return None

# %%
# Second transformation: match node name to entity list
def match_node_entity(node_name, node_nouns):
    """
    Case1: Node name is in the entity list. 
        Use the node name. For instance, if "LGBT Community" is in the entity list, use it directly.
    
    Case2: Node name is not in the entity list, but the noun list created from the previous step is not empty.
        Select the first noun from the noun list and find relevant entity for the selected noun.

        Case2-a: if a relevant entity is found, use the relevant entity as new node name. For instance, if the noun list is [france], relevant node is "France".

        Case2-b: if no relevant entity is found, use the select noun as new node name. For instance, if the noun list is [leader's stance], no relevant node is found. Therefore, "leader's stance" is used as the new node.
    
    Case3: If node name is not in the entity list and noun list is empty
        Return None
    """
    if node_name in entity_set:
        return node_name
    if len(node_nouns) > 0:
        node_name = node_nouns[0]
        return find_relevant_entity(node_name)
    return None

# %%
def find_relevant_entity(node_name):
    """
    Find the most relevant entity for the node name.
    Relevance is determined by the number of matched words.
    """
    entity_list = list(entity_set)
    if node_name in entity_set:
        return node_name
    match_perc = 0
    best_match = None
    node_words = node_name.lower().split()
    for ent in entity_list:
        ent_words = ent.lower().split()
        match_cnt = 0
        for w1 in node_words:
            for w2 in ent_words:
                if w1 == w2:
                    match_cnt += 1
        if (match_cnt/len(ent_words) >= 0.5) and (match_cnt/len(node_words) >= 0.5) and (match_cnt/len(ent_words) > match_perc):
            match_perc = match_cnt/len(ent_words)
            best_match = ent
    
    if best_match is not None:
        return best_match
    node_name = re.sub(r"’ s", '', node_name)
    node_name = re.sub(r"'s", '', node_name)
    return node_name

raw_relations['node1_t2'] = raw_relations.apply(lambda x: match_node_entity(x['subject'], x['node1_t1']), axis = 1)
raw_relations['node2_t2'] = raw_relations.apply(lambda x: match_node_entity(x['object'], x['node2_t1']), axis = 1)

# Select relations if both nodes are not None
filtered_relations = raw_relations[(raw_relations['node1_t2'].notnull()) & (raw_relations['node2_t2'].notnull())]
filtered_relations.head()
# Out:
#     news_id                    subject relation                       object  \
# 4         0           leader ’s stance     roil               LGBT community
# 10        0  Catholic leader ’s stance     roil               LGBT community
# 12        1                     France      Has  Historic New Prime Minister
# 13        1                     France      Has      Historic Prime Minister
# 14        1                     France      Has           New Prime Minister
#
#                         node1_t1           node2_t1                 node1_t2  \
# 4            [leader ’ s stance]             [lgbt]           leader  stance
# 10  [catholic leader ’ s stance]             [lgbt]  catholic leader  stance
# 12                      [france]  [historic, prime]                   France
# 13                      [france]   [historic prime]                   France
# 14                      [france]            [prime]                   France
#
#           node2_t2
# 4   LGBT community
# 10  LGBT community
# 12        historic
# 13  historic prime
# 14           prime

# %%
# Third transformation: deal with nodes with similar names within one news. For instance, "leader's stance" and "catholic leader's stance"

node_set = set(filtered_relations['node1_t2']).union(set(filtered_relations['node2_t2']))
node_list = sorted(list(node_set), key = lambda x: len(x))

def similar_node(node1, node2):
    """
    Determine if two nodes are similar.
    """
    node1_wl = node1.lower().split()
    node2_wl = node2.lower().split()
    matched_words = len(set(node1_wl) & set(node2_wl))
    word_match_ratio = matched_words / max(len(node1_wl), len(node2_wl))
    return word_match_ratio >= 0.5

final_node_list = list()
transformation_map = {}

for node in node_list:
    if node in entity_set:
        final_node_list.append(node)

for node in node_list:
    node_flag = False
    if node in entity_set:
        continue
    for fn in final_node_list:
        if similar_node(node, fn):
            transformation_map[node] = fn
            node_flag = True
        if node_flag:
            break
    if not node_flag: 
        final_node_list.append(node)

def transform_node(node_name):
    if node_name in transformation_map:
        return transformation_map[node_name].title()
    return node_name.title()

filtered_relations['node1_t3'] = filtered_relations.apply(lambda x: transform_node(x['node1_t2']), axis = 1)
filtered_relations['node2_t3'] = filtered_relations.apply(lambda x: transform_node(x['node2_t2']), axis = 1)
filtered_relations[:50]
# Out:
# /var/folders/b5/6fdjjrb57ln9w5w1477gvmbr0000gn/T/ipykernel_14185/4126785736.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_relations['node1_t3'] = filtered_relations.apply(lambda x: transform_node(x['node1_t2']), axis = 1)
# /var/folders/b5/6fdjjrb57ln9w5w1477gvmbr0000gn/T/ipykernel_14185/4126785736.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_relations['node2_t3'] = filtered_relations.apply(lambda x: transform_node(x['node2_t2']), axis = 1)
#     news_id                                subject                  relation  \
# 4         0                       leader ’s stance                      roil
# 10        0              Catholic leader ’s stance                      roil
# 12        1                                 France                       Has
# 13        1                                 France                       Has
# 14        1                                 France                       Has
# 15        1                                 France                       Has
# 18        2                       Ohio House votes                  override
# 19        2                       Ohio House votes                  override
# 20        2                       Ohio House votes    override sports ban on
# 21        2                             Ohio House                  override
# 23        4                             Ohio House                 overrides
# 25        4                             Ohio House                 overrides
# 26        4                           state Senate           will convene in
# 27        4                           state Senate     will convene later in
# 28        5                               Our Flag  Means Death runs aground
# 30        5                               Our Flag          Means Death runs
# 32        5                               Our Flag  Means Death runs aground
# 33        5                               Our Flag                     Means
# 34        5                               Our Flag             Means aground
# 36        5                               Our Flag          Means Death runs
# 37        5    Max 's beloved comedy pirate series                       has
# 38        5                                    Max                       has
# 39        5            Max 's comedy pirate series                       has
# 49        6                                    FTC                        ’s
# 53        7                                 France                      gets
# 55        7                                 France                      gets
# 56        7                                 France                      gets
# 59        7                          Gabriel Attal                    has as
# 60        7                          Gabriel Attal                    has as
# 61        7                          Gabriel Attal                    has as
# 62        7                          Gabriel Attal                    has as
# 68        8                 extremist organisation                     is in
# 72        9                                 France                        ’s
# 73        9                          Gabriel Attal                   becomes
# 74        9                          Gabriel Attal                   becomes
# 75        9                          Gabriel Attal                   becomes
# 76        9                          Gabriel Attal                   becomes
# 80       10                      his favorite jobs                     is in
# 85       11                         Chris Christie                       end
# 87       11  Former New Jersey Gov. Chris Christie                 is ending
# 89       11  Former New Jersey Gov. Chris Christie                 is ending
# 90       11  Former New Jersey Gov. Chris Christie                 is ending
# 91       12                              Louisiana                      over
# 92       12                            Trans youth                  sue over
# 93       12                            Trans youth                  sue over
# 94       12                            Trans youth                  sue over
# 95       12                            Trans youth                  sue over
# 97       13                       Mexico president            apologizes for
# 98       13                       Mexico president            apologizes for
# 99       13                       Mexico president            apologizes for
#
#                                               object  \
# 4                                     LGBT community
# 10                                    LGBT community
# 12                       Historic New Prime Minister
# 13                           Historic Prime Minister
# 14                                New Prime Minister
# 15                                    Prime Minister
# 18                                        sports ban
# 19                                  governor 's veto
# 20                                        trans care
# 21                          Gov. Mike DeWine ’s veto
# 23                            DeWine ’s veto of bill
# 25                                    DeWine ’s veto
# 26                                           January
# 27                                           January
# 28                      queer pirate comedy Max show
# 30                   as queer pirate comedy Max show
# 32                   as queer pirate comedy Max show
# 33                                        Death runs
# 34                                        Death runs
# 36                      queer pirate comedy Max show
# 37                          has sunk by Warner Bros.
# 38                      beloved comedy pirate series
# 39                          has sunk by Warner Bros.
# 49      first ban on selling sensitive location data
# 53                                     Gabriel Attal
# 55                           its ever prime minister
# 56                                its prime minister
# 59                       has France ’s ever minister
# 60                 has France ’s ever prime minister
# 61                            has France ’s minister
# 62                      has France ’s prime minister
# 68                                            Russia
# 72                           youngest prime minister
# 73                 France ’s youngest prime minister
# 74                          France ’s prime minister
# 75                       France ’s youngest minister
# 76                                France ’s minister
# 80                                            Hawaii
# 85                    his 2024 presidential campaign
# 87                   his 2024 campaign against Trump
# 89                    his 2024 presidential campaign
# 90      his 2024 presidential campaign against Trump
# 91               ban on gender affirming health care
# 92  Louisiana 's ban on gender affirming health care
# 93                                  Louisiana 's ban
# 94                   Louisiana 's ban on health care
# 95         Louisiana 's ban on affirming health care
# 97               trans lawmaker man dressed as woman
# 98                                trans lawmaker man
# 99                        trans lawmaker man dressed
#
#                           node1_t1                          node2_t1  \
# 4              [leader ’ s stance]                            [lgbt]
# 10    [catholic leader ’ s stance]                            [lgbt]
# 12                        [france]                 [historic, prime]
# 13                        [france]                  [historic prime]
# 14                        [france]                           [prime]
# 15                        [france]                           [prime]
# 18             [ohio, house votes]                      [sports ban]
# 19             [ohio, house votes]                [governor 's veto]
# 20             [ohio, house votes]                      [trans care]
# 21                          [ohio]      [gov, mike dewine, ’ s veto]
# 23                          [ohio]                [dewine, ’ s veto]
# 25                          [ohio]                [dewine, ’ s veto]
# 26                  [state senate]                         [january]
# 27                  [state senate]                         [january]
# 28                          [flag]        [queer pirate comedy, max]
# 30                          [flag]        [queer pirate comedy, max]
# 32                          [flag]        [queer pirate comedy, max]
# 33                          [flag]                           [death]
# 34                          [flag]                           [death]
# 36                          [flag]        [queer pirate comedy, max]
# 37     [max, comedy pirate series]                     [warner bros]
# 38                           [max]            [comedy pirate series]
# 39  [max, 's comedy pirate series]                     [warner bros]
# 49                           [ftc]         [sensitive location data]
# 53                        [france]                   [gabriel attal]
# 55                        [france]                  [prime minister]
# 56                        [france]                  [prime minister]
# 59                 [gabriel attal]                     [france, ’ s]
# 60                 [gabriel attal]     [france, ’ s, prime minister]
# 61                 [gabriel attal]            [france, ’ s minister]
# 62                 [gabriel attal]     [france, ’ s, prime minister]
# 68        [extremist organisation]                          [russia]
# 72                        [france]                  [prime minister]
# 73                 [gabriel attal]     [france, ’ s, prime minister]
# 74                 [gabriel attal]     [france, ’ s, prime minister]
# 75                 [gabriel attal]                     [france, ’ s]
# 76                 [gabriel attal]            [france, ’ s minister]
# 80                 [favorite jobs]                          [hawaii]
# 85                [chris christie]           [presidential campaign]
# 87    [jersey gov, chris christie]                           [trump]
# 89    [jersey gov, chris christie]           [presidential campaign]
# 90    [jersey gov, chris christie]    [presidential campaign, trump]
# 91                     [louisiana]                     [health care]
# 92                         [trans]  [louisiana, 's ban, health care]
# 93                         [trans]               [louisiana, 's ban]
# 94                         [trans]  [louisiana, 's ban, health care]
# 95                         [trans]  [louisiana, 's ban, health care]
# 97                        [mexico]              [trans lawmaker man]
# 98                        [mexico]              [trans lawmaker man]
# 99                        [mexico]              [trans lawmaker man]
#
#                    node1_t2                 node2_t2                node1_t3  \
# 4            leader  stance           LGBT community          Leader  Stance
# 10  catholic leader  stance           LGBT community          Leader  Stance
# 12                   France                 historic                  France
# 13                   France           historic prime                  France
# 14                   France                    prime                  France
# 15                   France                    prime                  France
# 18                     Ohio               sports ban                    Ohio
# 19                     Ohio           governor  veto                    Ohio
# 20                     Ohio               trans care                    Ohio
# 21                     Ohio                      gov                    Ohio
# 23                     Ohio                   DeWine                    Ohio
# 25                     Ohio                   DeWine                    Ohio
# 26             Polish state                  january            Polish State
# 27             Polish state                  january            Polish State
# 28                     flag      queer pirate comedy                    Flag
# 30                     flag      queer pirate comedy                    Flag
# 32                     flag      queer pirate comedy                    Flag
# 33                     flag                    death                    Flag
# 34                     flag                    death                    Flag
# 36                     flag      queer pirate comedy                    Flag
# 37               comedy Max              Warner Bros              Comedy Max
# 38               comedy Max     comedy pirate series              Comedy Max
# 39               comedy Max              Warner Bros              Comedy Max
# 49                      ftc  sensitive location data                     Ftc
# 53                   France                    Attal                  France
# 55                   France           prime minister                  France
# 56                   France           prime minister                  France
# 59                    Attal                   France                   Attal
# 60                    Attal                   France                   Attal
# 61                    Attal                   France                   Attal
# 62                    Attal                   France                   Attal
# 68   extremist organisation                   Russia  Extremist Organisation
# 72                   France           prime minister                  France
# 73                    Attal                   France                   Attal
# 74                    Attal                   France                   Attal
# 75                    Attal                   France                   Attal
# 76                    Attal                   France                   Attal
# 80            favorite jobs                   Hawaii           Favorite Jobs
# 85           Chris Christie    presidential campaign          Chris Christie
# 87               jersey gov                    trump                     Gov
# 89               jersey gov    presidential campaign                     Gov
# 90               jersey gov    presidential campaign                     Gov
# 91                Louisiana       Transgender Health               Louisiana
# 92                    trans                Louisiana                   Trans
# 93                    trans                Louisiana                   Trans
# 94                    trans                Louisiana                   Trans
# 95                    trans                Louisiana                   Trans
# 97                   Mexico       trans lawmaker man                  Mexico
# 98                   Mexico       trans lawmaker man                  Mexico
# 99                   Mexico       trans lawmaker man                  Mexico
#
#                    node2_t3
# 4            Lgbt Community
# 10           Lgbt Community
# 12                 Historic
# 13                    Prime
# 14                    Prime
# 15                    Prime
# 18               Sports Ban
# 19           Governor  Veto
# 20                    Trans
# 21                      Gov
# 23                   Dewine
# 25                   Dewine
# 26                  January
# 27                  January
# 28      Queer Pirate Comedy
# 30      Queer Pirate Comedy
# 32      Queer Pirate Comedy
# 33                    Death
# 34                    Death
# 36      Queer Pirate Comedy
# 37              Warner Bros
# 38      Queer Pirate Comedy
# 39              Warner Bros
# 49  Sensitive Location Data
# 53                    Attal
# 55                    Prime
# 56                    Prime
# 59                   France
# 60                   France
# 61                   France
# 62                   France
# 68                   Russia
# 72                    Prime
# 73                   France
# 74                   France
# 75                   France
# 76                   France
# 80                   Hawaii
# 85    Presidential Campaign
# 87                    Trump
# 89    Presidential Campaign
# 90    Presidential Campaign
# 91       Transgender Health
# 92                Louisiana
# 93                Louisiana
# 94                Louisiana
# 95                Louisiana
# 97       Trans Lawmaker Man
# 98       Trans Lawmaker Man
# 99       Trans Lawmaker Man

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def semantic_similarity(text1, text2):
    # Ensure inputs are strings
    doc1 = nlp(str(text1))
    doc2 = nlp(str(text2))
    return doc1.similarity(doc2)

# %%
# Third transformation: deal with nodes with similar names within one news. For instance, "leader's stance" and "catholic leader's stance"

node_set = set(filtered_relations['node1_t2']).union(set(filtered_relations['node2_t2']))
node_list = sorted(list(node_set), key = lambda x: len(x))

def similar_node(node1, node2):
    """
    Determine if two nodes are similar, using both word match and semantic similarity.
    """
    # Word match calculation
    node1_wl = node1.lower().split()
    node2_wl = node2.lower().split()
    matched_words = len(set(node1_wl) & set(node2_wl))
    word_match_ratio = matched_words / max(len(node1_wl), len(node2_wl))
    
    # Semantic similarity calculation
    semantic_similarity_score = semantic_similarity(node1, node2)

    # Compare results
    word_match_result = word_match_ratio >= 0.5
    semantic_similarity_result = semantic_similarity_score >= 0.8
    
    # Return True if either method indicates similarity
    return word_match_result or semantic_similarity_result

final_node_list = list()
transformation_map = {}

for node in node_list:
    if node in entity_set:
        final_node_list.append(node)

for node in node_list:
    node_flag = False
    if node in entity_set:
        continue
    for fn in final_node_list:
        if similar_node(node, fn):
            transformation_map[node] = fn
            node_flag = True
        if node_flag:
            break
    if not node_flag: 
        final_node_list.append(node)

def transform_node(node_name):
    if node_name in transformation_map:
        return transformation_map[node_name].title()
    return node_name.title()

filtered_relations['node1_t3'] = filtered_relations.apply(lambda x: transform_node(x['node1_t2']), axis = 1)
filtered_relations['node2_t3'] = filtered_relations.apply(lambda x: transform_node(x['node2_t2']), axis = 1)
filtered_relations[:50]
# Out:
# /var/folders/b5/6fdjjrb57ln9w5w1477gvmbr0000gn/T/ipykernel_14185/3279710871.py:8: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   return doc1.similarity(doc2)
# /var/folders/b5/6fdjjrb57ln9w5w1477gvmbr0000gn/T/ipykernel_14185/579510474.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_relations['node1_t3'] = filtered_relations.apply(lambda x: transform_node(x['node1_t2']), axis = 1)
# /var/folders/b5/6fdjjrb57ln9w5w1477gvmbr0000gn/T/ipykernel_14185/579510474.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_relations['node2_t3'] = filtered_relations.apply(lambda x: transform_node(x['node2_t2']), axis = 1)
#     news_id                                subject                  relation  \
# 4         0                       leader ’s stance                      roil
# 10        0              Catholic leader ’s stance                      roil
# 12        1                                 France                       Has
# 13        1                                 France                       Has
# 14        1                                 France                       Has
# 15        1                                 France                       Has
# 18        2                       Ohio House votes                  override
# 19        2                       Ohio House votes                  override
# 20        2                       Ohio House votes    override sports ban on
# 21        2                             Ohio House                  override
# 23        4                             Ohio House                 overrides
# 25        4                             Ohio House                 overrides
# 26        4                           state Senate           will convene in
# 27        4                           state Senate     will convene later in
# 28        5                               Our Flag  Means Death runs aground
# 30        5                               Our Flag          Means Death runs
# 32        5                               Our Flag  Means Death runs aground
# 33        5                               Our Flag                     Means
# 34        5                               Our Flag             Means aground
# 36        5                               Our Flag          Means Death runs
# 37        5    Max 's beloved comedy pirate series                       has
# 38        5                                    Max                       has
# 39        5            Max 's comedy pirate series                       has
# 49        6                                    FTC                        ’s
# 53        7                                 France                      gets
# 55        7                                 France                      gets
# 56        7                                 France                      gets
# 59        7                          Gabriel Attal                    has as
# 60        7                          Gabriel Attal                    has as
# 61        7                          Gabriel Attal                    has as
# 62        7                          Gabriel Attal                    has as
# 68        8                 extremist organisation                     is in
# 72        9                                 France                        ’s
# 73        9                          Gabriel Attal                   becomes
# 74        9                          Gabriel Attal                   becomes
# 75        9                          Gabriel Attal                   becomes
# 76        9                          Gabriel Attal                   becomes
# 80       10                      his favorite jobs                     is in
# 85       11                         Chris Christie                       end
# 87       11  Former New Jersey Gov. Chris Christie                 is ending
# 89       11  Former New Jersey Gov. Chris Christie                 is ending
# 90       11  Former New Jersey Gov. Chris Christie                 is ending
# 91       12                              Louisiana                      over
# 92       12                            Trans youth                  sue over
# 93       12                            Trans youth                  sue over
# 94       12                            Trans youth                  sue over
# 95       12                            Trans youth                  sue over
# 97       13                       Mexico president            apologizes for
# 98       13                       Mexico president            apologizes for
# 99       13                       Mexico president            apologizes for
#
#                                               object  \
# 4                                     LGBT community
# 10                                    LGBT community
# 12                       Historic New Prime Minister
# 13                           Historic Prime Minister
# 14                                New Prime Minister
# 15                                    Prime Minister
# 18                                        sports ban
# 19                                  governor 's veto
# 20                                        trans care
# 21                          Gov. Mike DeWine ’s veto
# 23                            DeWine ’s veto of bill
# 25                                    DeWine ’s veto
# 26                                           January
# 27                                           January
# 28                      queer pirate comedy Max show
# 30                   as queer pirate comedy Max show
# 32                   as queer pirate comedy Max show
# 33                                        Death runs
# 34                                        Death runs
# 36                      queer pirate comedy Max show
# 37                          has sunk by Warner Bros.
# 38                      beloved comedy pirate series
# 39                          has sunk by Warner Bros.
# 49      first ban on selling sensitive location data
# 53                                     Gabriel Attal
# 55                           its ever prime minister
# 56                                its prime minister
# 59                       has France ’s ever minister
# 60                 has France ’s ever prime minister
# 61                            has France ’s minister
# 62                      has France ’s prime minister
# 68                                            Russia
# 72                           youngest prime minister
# 73                 France ’s youngest prime minister
# 74                          France ’s prime minister
# 75                       France ’s youngest minister
# 76                                France ’s minister
# 80                                            Hawaii
# 85                    his 2024 presidential campaign
# 87                   his 2024 campaign against Trump
# 89                    his 2024 presidential campaign
# 90      his 2024 presidential campaign against Trump
# 91               ban on gender affirming health care
# 92  Louisiana 's ban on gender affirming health care
# 93                                  Louisiana 's ban
# 94                   Louisiana 's ban on health care
# 95         Louisiana 's ban on affirming health care
# 97               trans lawmaker man dressed as woman
# 98                                trans lawmaker man
# 99                        trans lawmaker man dressed
#
#                           node1_t1                          node2_t1  \
# 4              [leader ’ s stance]                            [lgbt]
# 10    [catholic leader ’ s stance]                            [lgbt]
# 12                        [france]                 [historic, prime]
# 13                        [france]                  [historic prime]
# 14                        [france]                           [prime]
# 15                        [france]                           [prime]
# 18             [ohio, house votes]                      [sports ban]
# 19             [ohio, house votes]                [governor 's veto]
# 20             [ohio, house votes]                      [trans care]
# 21                          [ohio]      [gov, mike dewine, ’ s veto]
# 23                          [ohio]                [dewine, ’ s veto]
# 25                          [ohio]                [dewine, ’ s veto]
# 26                  [state senate]                         [january]
# 27                  [state senate]                         [january]
# 28                          [flag]        [queer pirate comedy, max]
# 30                          [flag]        [queer pirate comedy, max]
# 32                          [flag]        [queer pirate comedy, max]
# 33                          [flag]                           [death]
# 34                          [flag]                           [death]
# 36                          [flag]        [queer pirate comedy, max]
# 37     [max, comedy pirate series]                     [warner bros]
# 38                           [max]            [comedy pirate series]
# 39  [max, 's comedy pirate series]                     [warner bros]
# 49                           [ftc]         [sensitive location data]
# 53                        [france]                   [gabriel attal]
# 55                        [france]                  [prime minister]
# 56                        [france]                  [prime minister]
# 59                 [gabriel attal]                     [france, ’ s]
# 60                 [gabriel attal]     [france, ’ s, prime minister]
# 61                 [gabriel attal]            [france, ’ s minister]
# 62                 [gabriel attal]     [france, ’ s, prime minister]
# 68        [extremist organisation]                          [russia]
# 72                        [france]                  [prime minister]
# 73                 [gabriel attal]     [france, ’ s, prime minister]
# 74                 [gabriel attal]     [france, ’ s, prime minister]
# 75                 [gabriel attal]                     [france, ’ s]
# 76                 [gabriel attal]            [france, ’ s minister]
# 80                 [favorite jobs]                          [hawaii]
# 85                [chris christie]           [presidential campaign]
# 87    [jersey gov, chris christie]                           [trump]
# 89    [jersey gov, chris christie]           [presidential campaign]
# 90    [jersey gov, chris christie]    [presidential campaign, trump]
# 91                     [louisiana]                     [health care]
# 92                         [trans]  [louisiana, 's ban, health care]
# 93                         [trans]               [louisiana, 's ban]
# 94                         [trans]  [louisiana, 's ban, health care]
# 95                         [trans]  [louisiana, 's ban, health care]
# 97                        [mexico]              [trans lawmaker man]
# 98                        [mexico]              [trans lawmaker man]
# 99                        [mexico]              [trans lawmaker man]
#
#                    node1_t2                 node2_t2                 node1_t3  \
# 4            leader  stance           LGBT community           Governor  Veto
# 10  catholic leader  stance           LGBT community  Catholic Leader  Stance
# 12                   France                 historic                   France
# 13                   France           historic prime                   France
# 14                   France                    prime                   France
# 15                   France                    prime                   France
# 18                     Ohio               sports ban                     Ohio
# 19                     Ohio           governor  veto                     Ohio
# 20                     Ohio               trans care                     Ohio
# 21                     Ohio                      gov                     Ohio
# 23                     Ohio                   DeWine                     Ohio
# 25                     Ohio                   DeWine                     Ohio
# 26             Polish state                  january             Polish State
# 27             Polish state                  january             Polish State
# 28                     flag      queer pirate comedy                     Flag
# 30                     flag      queer pirate comedy                     Flag
# 32                     flag      queer pirate comedy                     Flag
# 33                     flag                    death                     Flag
# 34                     flag                    death                     Flag
# 36                     flag      queer pirate comedy                     Flag
# 37               comedy Max              Warner Bros               Comedy Max
# 38               comedy Max     comedy pirate series               Comedy Max
# 39               comedy Max              Warner Bros               Comedy Max
# 49                      ftc  sensitive location data                      Ftc
# 53                   France                    Attal                   France
# 55                   France           prime minister                   France
# 56                   France           prime minister                   France
# 59                    Attal                   France                    Attal
# 60                    Attal                   France                    Attal
# 61                    Attal                   France                    Attal
# 62                    Attal                   France                    Attal
# 68   extremist organisation                   Russia   Extremist Organisation
# 72                   France           prime minister                   France
# 73                    Attal                   France                    Attal
# 74                    Attal                   France                    Attal
# 75                    Attal                   France                    Attal
# 76                    Attal                   France                    Attal
# 80            favorite jobs                   Hawaii            Favorite Jobs
# 85           Chris Christie    presidential campaign           Chris Christie
# 87               jersey gov                    trump                      Gov
# 89               jersey gov    presidential campaign                      Gov
# 90               jersey gov    presidential campaign                      Gov
# 91                Louisiana       Transgender Health                Louisiana
# 92                    trans                Louisiana                    Trans
# 93                    trans                Louisiana                    Trans
# 94                    trans                Louisiana                    Trans
# 95                    trans                Louisiana                    Trans
# 97                   Mexico       trans lawmaker man                   Mexico
# 98                   Mexico       trans lawmaker man                   Mexico
# 99                   Mexico       trans lawmaker man                   Mexico
#
#                    node2_t3
# 4            Lgbt Community
# 10           Lgbt Community
# 12                 Historic
# 13                    Prime
# 14                    Prime
# 15                    Prime
# 18               Sports Ban
# 19           Governor  Veto
# 20                    Trans
# 21                      Gov
# 23                   Dewine
# 25                   Dewine
# 26                  January
# 27                  January
# 28      Queer Pirate Comedy
# 30      Queer Pirate Comedy
# 32      Queer Pirate Comedy
# 33                    Death
# 34                    Death
# 36      Queer Pirate Comedy
# 37              Warner Bros
# 38        University Rector
# 39              Warner Bros
# 49  Sensitive Location Data
# 53                    Attal
# 55                    Prime
# 56                    Prime
# 59                   France
# 60                   France
# 61                   France
# 62                   France
# 68                   Russia
# 72                    Prime
# 73                   France
# 74                   France
# 75                   France
# 76                   France
# 80                   Hawaii
# 85          Political Party
# 87                    Trump
# 89          Political Party
# 90          Political Party
# 91       Transgender Health
# 92                Louisiana
# 93                Louisiana
# 94                Louisiana
# 95                Louisiana
# 97       Trans Lawmaker Man
# 98       Trans Lawmaker Man
# 99       Trans Lawmaker Man

# %%
# Forth transformation: drop duplicate relations within one news

transformed_relations = filtered_relations.drop_duplicates(subset = ['news_id', 'node1_t3', 'node2_t3'], keep ='first')
transformed_relations.head()
# transformed_relations.to_csv(output_path + "/transformed_relations.csv")
# Out:
#     news_id           subject  relation                       object  \
# 4         0  leader ’s stance      roil               LGBT community
# 12        1            France       Has  Historic New Prime Minister
# 13        1            France       Has      Historic Prime Minister
# 18        2  Ohio House votes  override                   sports ban
# 19        2  Ohio House votes  override             governor 's veto
#
#                node1_t1            node2_t1        node1_t2        node2_t2  \
# 4   [leader ’ s stance]              [lgbt]  leader  stance  LGBT community
# 12             [france]   [historic, prime]          France        historic
# 13             [france]    [historic prime]          France  historic prime
# 18  [ohio, house votes]        [sports ban]            Ohio      sports ban
# 19  [ohio, house votes]  [governor 's veto]            Ohio  governor  veto
#
#           node1_t3        node2_t3
# 4   Leader  Stance  Lgbt Community
# 12          France        Historic
# 13          France           Prime
# 18            Ohio      Sports Ban
# 19            Ohio  Governor  Veto
